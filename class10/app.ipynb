# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
a = np.zeros(10)
# print(type(a))
type(a[0])
# Out:
# numpy.float64

# %%
a = np.ones(12)
a[0].dtype
# Out:
# dtype('float64')

# %%
a = np.array([[1.123,2,3,4,5],[1.123,2,3,4,5]])
# a.reshape(5,2)

for val in a:
    print(val)
# Out:
# [1.123 2.    3.    4.    5.   ]
# [1.123 2.    3.    4.    5.   ]

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6, 7])

filter_arr = arr % 2 == 0

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False  True False  True False  True False]
# [2 4 6]
