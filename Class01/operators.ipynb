# %% [markdown]
# # Arithemetic Operator

# %%
a = -5 
b = 2

# %%
c = a+b 
c = a-b
c = a*b
c = a/b

a ** b
a % b
a // b
# Out:
# -3

# %% [markdown]
# # Assignment Operator

# %%
a = -5 
a //= 2  # a = a+2
a
# Out:
# -3

# %% [markdown]
#  # comparison operatory

# %%
a = 2 
b = 2 
c = 10

# %%
not a == 2
# Out:
# False

# %%
b = 2
a  is not  b
# Out:
# False

# %%
a = [1,2,4,"jhell",[123,123]]

[123] in a
# Out:
# False
